# %%
using Plots

# %%
using DataFrames, CSV

# %%
data = CSV.read("runtime.csv", DataFrame)
# Out:
# 10×2 DataFrame
#  Row │ tool         runtime
#      │ String15     Float64
# ─────┼──────────────────────
#    1 │ python       714.0
#    2 │ julia          6.349
#    3 │ R            510.4
#    4 │ perl         235.0
#    5 │ c++           37.97
#    6 │ c++ (o)       23.74
#    7 │ c++ (c)        2.205
#    8 │ fortran (c)    2.242
#    9 │ rust           5.241
#   10 │ julia (o)      1.986

# %%
scatter(data.tool,data.runtime,leg=false,markersize=7,labelsize=20)

# %%
scatter(data.tool,data.runtime,leg=false,yaxis=(:log10),markersize=7)
