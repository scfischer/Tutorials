// %% [markdown]
// # Performance of Rust
// ### Exemplary Problem: Numerical solution of logistic differential equation
// $\frac{\partial U(t)}{\partial t} = U(t)(1-U(t))$
//
// Strategy:
// Transform into discrete sequence and calculate the single steps for sufficient small time steps $\Delta t$.
//
// $U(t+\Delta t) =U(t)+ U(t)(1-U(t))\Delta t $

// %% [markdown]
// First step: Install and import neccesary packages

// %%
use std::*;
use std::collections::HashMap;

// %% [markdown]
// Second step: Define function for discretisation with number of steps N as input argument

// %%
fn rust_logistic(N: u32) -> Vec<f64> {
    let T = 25;
    let u0 = 1e-05;
    let f = |u| (u*(1.0 - u));
    let mut t = vec![0.0; N as usize];
    let dt = (T as f64)/(N as f64);
    let mut u = vec![0.0; N as usize];
    u[0] = u0;
    for k in 0..(N - 1) {
        t[k as usize] = (k as f64)*dt;
        u[(k + 1) as usize] = u[k as usize] + (dt*f(u[k as usize]));
    }
    //return (t, u);
    return u
}

// %% [markdown]
// Third step: Run the function, to so see if everthing works as planned

// %%
rust_logistic(1000)
// Out:
// [0.00001, 0.000010249997500000002, 0.000010506244810938783, 0.000010768898171682752, 0.000011038117726745626, 0.000011314067623913192, 0.000011596916114307867, 0.00001188683565495398, 0.000012184003013906282, 0.000012488599378005703, 0.000012800810463327985, 0.000013120826628392472, 0.000013448842990199998, 0.000013785059543170554, 0.000014129681281053153, 0.000014482918321882155, 0.00001484498603605613, 0.000015216105177617273, 0.000015596502018811285, 0.000015986408488009686, 0.00001638606231107852, 0.000016795707156279532, 0.000017215592782792047, 0.000017645975192945976, 0.000018087116788258614, 0.000018539286529370238, 0.00001900276009997587, 0.00001947782007485298, 0.000019964756092087432, 0.000020463865029602473, 0.000020975451186098236, 0.00002149982646651188, 0.000022037310572111227, 0.000022588231195337578, 0.000023152924219516305, 0.000023731733923556715, 0.000024325013191765756, 0.000024933123728903232, 0.00002555643628060934, 0.00002619533085933869, 0.000026850196975938187, 0.0000275214338770097, 0.00002820945078820188, 0.000028914667163579083, 0.00002963751294121913, 0.000030378428805195273, 0.00003113786645410174, 0.0000319162888762861, 0.00003271417063195586, 0.00003353199814233076, 0.00003437026998601654, 0.00003522949720278048, 0.00003611020360491316, 0.00003701292609636588, 0.00003793821499985757, 0.00003888663439215008, 0.00003985876244769547, 0.00004085519179086426, 0.00004187652985696846, 0.00004292339926229885, 0.000043996438183401215, 0.000045096300745821926, 0.00004622365742255895, 0.000047379195442460286, 0.000048563619208817774, 0.000049777650728410455, 0.00005102203005125792, 0.0000522975157213506, 0.0000536048852386306, 0.00005494493553250333, 0.000056318483447167395, 0.00005772636623905714, 0.00005916944208669959, 0.000060648590613295154, 0.00006216471342233894, 0.00006371873464660755, 0.00006531160151084412, 0.00006694428490848292, 0.00006861777999276293, 0.00007033310678258873, 0.00007209131078350571, 0.0000738934636241661, 0.00007574066370867109, 0.0000776340368851844, 0.00007957473713122193, 0.00008156394725603273, 0.00008360287962049625, 0.00008569277687497164, 0.00008783491271554572, 0.00009003059265913707, 0.00009228115483792513, 0.0000945879708135848, 0.00009695244641181886, 0.0000993760225776927, 0.00010186017625228844, 0.000104406421271208, 0.00010701630928546813, 0.0001096914307053435, 0.00011243341566772784, 0.00011524393502759708, 0.00011812470137417298, 0.00012107747007240044, 0.00012410404033036648, 0.00012720625629330498, 0.0001303860081648466, 0.00013364523335618962, 0.0001369859176638844, 0.00014041009647694055, 0.00014391985601398425, 0.00014751733459121, 0.00015120472392189012, 0.00015498427044822397, 0.00015885827670632742, 0.00016282910272518366, 0.0001668991674603959, 0.00017107095026360332, 0.0001753469923884428, 0.00017972989853396037, 0.0001842223384263987, 0.00018882704844030927, 0.00019354683325996144, 0.00019838456758204385, 0.0002033431978606786, 0.00020842574409579264, 0.00021363530166591742, 0.00021897504320651242, 0.00022444822053493656, 0.00023005816662321745, 0.00023580829761979714, 0.0002417021149214614, 0.000247743207296689, 0.0002539352530616872, 0.0002602820223104107, 0.0002667873791998925, 0.0002734552842922473, 0.00028028979695474083, 0.00028729507781935244, 0.00029447539130329276, 0.000301835108191973, 0.0003093787082859589, 0.00031711078311347934, 0.00032503603871009715, 0.00033315929846718806, 0.0003414855060509139, 0.00035001972839341565, 0.00035876715875799445, 0.0003677331198800892, 0.00037692306718590504, 0.0003863425920905882, 0.00039599742537789137, 0.000405893440663316, 0.00041603665794276955, 0.00042643324722882, 0.0004370895322766819, 0.0004480119944021183, 0.00045920727639349305, 0.00047068218652026304, 0.0004824437026402519, 0.0004944989764081028, 0.0005068553375873636, 0.0005195202984687167, 0.0005325015583969216, 0.0005458070084091022, 0.0005594447359870691, 0.0005734230299264302, 0.0005877503853253098, 0.0006024355086955563, 0.0006174873231 ...

// %% [markdown]
// Fourth step: Benchmark the function

// %%
use std::time::Instant;
let start = Instant::now();
for k in 0..1000000 {
    rust_logistic(1000);    
}
let end = Instant::now();
let duration = (end-start).subsec_nanos();
println!("{} nano seconds for whatever you did.", duration/1000000);
// Out:
// 373 nano seconds for whatever you did.

// %% [markdown]
// Fifth step: Realize that even this shitty rust code, which was just hacked together without any knowledge of the language, is super fast.
